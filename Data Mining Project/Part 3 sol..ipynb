# %%
#processing input1 , input2 and writting in input3 for further processing. 
data = data2 = "" 
  
# Reading data from file1 
with open('input1.txt') as fp: 
    data = fp.read() 
  

with open('input2.txt') as fp: 
    data2 = fp.read() 
  
 
data += "\n"
data += data2 
  
with open ('input3.txt', 'w') as fp: 
    fp.write(data)

# %%
from collections import Counter
def word_count(fname):
        with open(fname) as f:
                return Counter(f.read().split())

print("The number of words with a specific amount of letters in both input file :",word_count("input3.txt"))
# Out:
# The number of words with a specific amount of letters in both input file : Counter({'the': 3071, 'I': 2759, 'and': 2349, 'of': 2190, 'to': 2119, 'a': 1513, 'in': 1428, 'my': 1370, 'that': 1156, 'you': 1115, 'is': 962, 'not': 927, 'with': 803, 'his': 777, 'for': 763, 'it': 738, 'And': 710, 'have': 700, 'he': 689, 'be': 685, 'me': 650, 'your': 630, 'as': 553, 'thou': 547, 'this': 517, 'but': 516, 'The': 515, 'thy': 504, 'was': 483, 'will': 446, 'so': 403, 'him': 400, 'by': 380, 'all': 375, 'do': 375, 'no': 354, 'had': 350, 'are': 339, 'her': 336, 'from': 333, 'which': 329, 'That': 327, 'But': 320, 'at': 313, 'To': 313, 'shall': 311, 'we': 301, 'our': 300, 'or': 297, 'on': 296, 'what': 289, 'would': 265, 'love': 263, 'if': 259, 'more': 252, 'thee': 246, 'am': 246, 'good': 235, 'their': 229, 'when': 223, 'than': 221, 'they': 221, 'she': 215, 'If': 212, 'He': 208, 'CLEOPATRA.': 205, 'Enter': 204, 'ANTONY.': 202, 'ROSALIND.': 201, 'were': 196, 'should': 193, 'an': 192, 'A': 192, 'did': 189
# ...
